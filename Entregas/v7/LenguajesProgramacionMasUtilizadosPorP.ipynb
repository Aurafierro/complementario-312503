# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Cargar el archivo CSV con el delimitador correcto
file_path = 'LenguajesProgramacionMasUtilizadosPorP.Avanzados.csv'
df = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1')

# Verificar las primeras filas del dataframe y los nombres de las columnas
print("Nombres de las columnas:")
print(df.columns)  # Ver los nombres de las columnas para confirmar que todo esté correcto
print("\nPrimeras filas del dataframe:")
print(df.head())  # Ver las primeras filas para revisar que los datos se hayan cargado correctamente


# Eliminar el signo de porcentaje (%) y convertir los valores a tipo float
df['Porcentaje de uso'] = df['Porcentaje de uso'].str.rstrip('%').astype(float)
df['Porcentaje de adopción en empresas'] = df['Porcentaje de adopción en empresas'].str.rstrip('%').astype(float)

# Paso 4: Crear el diagrama de correlación lineal
plt.figure(figsize=(10, 6))  # Tamaño del gráfico
sns.regplot(x='Porcentaje de uso', y='Porcentaje de adopción en empresas', data=df,
            scatter_kws={'s':100}, line_kws={'color':'red'})  # Diagrama de dispersión con regresión

# Agregar título y etiquetas
plt.title('Correlación entre Porcentaje de Uso y Adopción en Empresas', fontsize=16)
plt.xlabel('Porcentaje de Uso', fontsize=12)
plt.ylabel('Porcentaje de Adopción en Empresas', fontsize=12)

# Mostrar el gráfico
plt.show()
# Out:
# Nombres de las columnas:
# Index(['Lenguaje', 'Porcentaje de uso', 'Facilidad de Aprendizaje',
#        'Uso en Investigación', 'Porcentaje de adopción en empresas'],
#       dtype='object')
#
# Primeras filas del dataframe:
#      Lenguaje Porcentaje de uso  Facilidad de Aprendizaje  \
# 0      Python             85.3%                       9.0
# 1  JavaScript             85.3%                       8.0
# 2        Java             85.3%                       7.0
# 3         C++             83.8%                       6.0
# 4          C#             73.5%                       8.0
#
#    Uso en Investigación Porcentaje de adopción en empresas
# 0                   8.0                                40%
# 1                   7.0                                35%
# 2                   7.0                                60%
# 3                   8.0                                50%
# 4                   6.0                                55%
